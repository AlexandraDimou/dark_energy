# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import lmfit
import corner

# %%
#Define Hubble parameter.I am using Wetterich parametrization: w(z)=w0/[1+w1*ln(1+z)]^2 
def Hz1(z1,H01,Om1,w0,w1):
    #the redshift dependence of the dark energy density using Wetterich parametrization:
    w_z=w0/(1+w1*np.log(1+z1))**2
    I=(1+z1)**(3+3*w_z)
    E = np.sqrt((Om1*(1+z1)**3.) + (1-Om1)*I)
    HZ1 = H01*E
    return HZ1

# %%
#Define  random redshifts
num_zs = 1000
zs= np.linspace(0.01, 1000., num=num_zs)

# %%
O_m=0.3029
w_0=-0.9414
w_1=0.17
H_0=68.5265

# %%
#Hubble comoving parameter
Hz=Hz1(zs,H_0,O_m,w_0,w_1)/(1+zs)

# %%
#random error for Hz
error_sigma = 0.5
e1 = np.random.normal(0., error_sigma, Hz.shape)

# %%
H_zz= Hz + e1

# %%
plt.plot(zs,H_zz, '.')

# %%
p = lmfit.Parameters()
p.add_many(('Om1',0.3,True,0.,2.),
           ('H01',70.,True,50.,100.),
           ('w0',-1.,True,-3.,3.),
           ('w1',0.2,True,-2.,2.))

def residual(p):
    v = p.valuesdict()
    return (Hz1(zs,v['H01'],v['Om1'],v['w0'],v['w1'])/(1+zs)-H_zz)/error_sigma

# %%
mi = lmfit.minimize(residual, p, method='leastsq', nan_policy='omit')

# %%
plt.errorbar(zs,H_zz,yerr=error_sigma,fmt='o',alpha=0.2)
#bestOde1= mi.params.valuesdict()['Ode1']
bestOm1 = mi.params.valuesdict()['Om1']
bestH01 = mi.params.valuesdict()['H01']
bestw0 = mi.params.valuesdict()['w0']
bestw1 = mi.params.valuesdict()['w1']
plt.plot(zs,Hz1(zs,bestH01,bestOm1,bestw0,bestw1)/(1+zs))
plt.plot(zs,Hz)
plt.xlabel('Redshift (z)')
plt.ylabel('Comoving Hubble parameter')
lmfit.report_fit(mi)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 21
#     # data points      = 1000
#     # variables        = 4
#     chi-square         = 991.910923
#     reduced chi-square = 0.99589450
#     Akaike info crit   = -0.12197099
#     Bayesian info crit = 19.5090501
# [[Variables]]
#     Om1:  0.29945679 +/- 0.00422953 (1.41%) (init = 0.3)
#     H01:  69.0545574 +/- 0.50052891 (0.72%) (init = 70)
#     w0:  -0.96303267 +/- 0.01379153 (1.43%) (init = -1)
#     w1:   0.16854448 +/- 0.00111182 (0.66%) (init = 0.2)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Om1, H01) = -0.991
#     C(H01, w0)  = -0.585
#     C(Om1, w0)  =  0.486

# %%
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=300, steps=1500, thin=1,
                         params=p, is_weighted=True)

# %%
corner.corner(res.flatchain,labels=res.var_names, truths=list(res.params.valuesdict().values()))
# Out:
# WARNING:root:Too few points to create valid contours
