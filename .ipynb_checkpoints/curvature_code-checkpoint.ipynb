# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import lmfit
import astropy
import astropy.units as u
import corner
from astropy.cosmology import LambdaCDM

# %%
def Hz1(z1,H01,Om1,Ode1,Ok1):
    #cosmo =LambdaCDM(H0=H01* u.km / u.s / u.Mpc, Om0=Om1, Ode0=Ode1) 
    E =np.sqrt(Om1*((1+z1)**3) + Ok1*((1+z1)**2) + Ode1)
    #E=cosmo.efunc(z1)
    HZ1 = H01*E
    return HZ1

# %%
#Define  random redshifts
num_zs = 1000
zs= np.linspace(0.01,4., num=num_zs)

# %%
O_m=0.3111
O_de=0.6889
H_0=67.66
O_k=-0.04

# %%
Hz=Hz1(zs,H_0,O_m,O_de,O_k)/(1+zs)

# %%
#random error for Hz
error_sigma = 0.5
e1 = np.random.normal(0., error_sigma, Hz.shape)

# %%
H_zz= Hz + e1

# %%
plt.plot(zs,H_zz, '.')

# %%
p = lmfit.Parameters()
p.add_many(('Om1',0.3,True,0.,2.),
           ('H01',70.,True,50.,100.),
           ('Ode1',0.7,True,0.,2.),
           ('Ok1',-0.04,True,-0.2,0.))

def residual(p):
    v = p.valuesdict()
    return (Hz1(zs,v['H01'],v['Om1'],v['Ode1'],v['Ok1'])/(1+zs)-H_zz)/error_sigma

# %%
mi = lmfit.minimize(residual, p, method='leastsq', nan_policy='omit')

# %%
fig = plt.figure(figsize=(18,12))
plt.errorbar(zs,H_zz,yerr=error_sigma,fmt='_',alpha=0.3)
bestOm1 = mi.params.valuesdict()['Om1']
bestH01 = mi.params.valuesdict()['H01']
bestOde1 = mi.params.valuesdict()['Ode1']
bestOk1 =mi.params.valuesdict()['Ok1']
plt.plot(zs,Hz1(zs,bestH01,bestOm1,bestOde1,bestOk1)/(1+zs))
plt.plot(zs,Hz)
plt.xlabel('Redshift (z)')
plt.ylabel('Comoving Hubble parameter')
lmfit.report_fit(mi)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 1000
#     # variables        = 4
#     chi-square         = 983.997943
#     reduced chi-square = 0.98794974
#     Akaike info crit   = -8.13147245
#     Bayesian info crit = 11.4995487
# [[Variables]]
#     Om1:   0.25354698 +/- 8.43885649 (3328.32%) (init = 0.3)
#     H01:   75.0020461 +/- 1249.25455 (1665.63%) (init = 70)
#     Ode1:  0.56547776 +/- 18.8189228 (3327.97%) (init = 0.7)
#     Ok1:  -0.03507685 +/- 1.16747954 (3328.35%) (init = -0.04)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Om1, H01)  = -1.000
#     C(Om1, Ode1) =  1.000
#     C(H01, Ode1) = -1.000
#     C(Ode1, Ok1) = -1.000
#     C(Om1, Ok1)  = -1.000
#     C(H01, Ok1)  =  1.000

# %%
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=300, steps=1500,thin=1,
                         params=p, is_weighted=True)

# %%
corner.corner(res.flatchain,labels=res.var_names, truths=list(res.params.valuesdict().values()))
