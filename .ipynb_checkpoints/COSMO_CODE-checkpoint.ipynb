# %%
# %matplotlib inline
import numpy as np
import lmfit
import matplotlib.pyplot as plt
import pandas as pd
import corner
import astropy
import astropy.units as u
#import numba

# %%
columns=['name','redshift','distance_mod','DM_err','SN_prob']
rawdat=pd.read_csv('SCPUnion2.1_mu_vs_z.txt', sep='\s',names=columns, header=5, engine='python')

# %%
data=np.sort(rawdat.T, axis=0)
zs = rawdat.redshift
mm = rawdat.distance_mod
dm = rawdat.DM_err

# %%
from astropy.cosmology import wCDM

# %%
#because the equation of state must be constant
def w0() :
    return "w0"

# %%
#@numba.jit
def DM(z,H0,Om,Ode,w0):
    cosmo = wCDM(H0=H0* u.km / u.s / u.Mpc, Om0=Om,Ode0=Ode)
    DL=cosmo.luminosity_distance(z)
    mag=5*np.log10((DL/(10*u.pc)).decompose())
    wz=cosmo.w(z)
    return mag

# %%
#np.seterr(divide='ignore', invalid='ignore')

# %%
p = lmfit.Parameters()
p.add_many(('Om',0.3,True,0.,2.),('H0',70.0,True,50.,100.),('Ode',0.7,True,0.,2.),('w0',-1.0,True,-2.,2.))

def residual(p):
    v = p.valuesdict()
    return (DM(zs,v['H0'],v['Om'],v['Ode'],v['w0'])-mm)/dm

# %%
print p
# Out:
# Parameters([('Om', <Parameter 'Om', 0.3, bounds=[0.0:2.0]>), ('H0', <Parameter 'H0', 70.0, bounds=[50.0:100.0]>), ('Ode', <Parameter 'Ode', 0.7, bounds=[0.0:2.0]>), ('w0', <Parameter 'w0', -1.0, bounds=[-2.0:2.0]>)])

# %%
mi = lmfit.minimize(residual, p, method='nelder', nan_policy='omit')

# %%
s = (zs.sort_values()).index
plt.errorbar(zs[s],mm[s],yerr=dm[s],fmt='o',alpha=0.4)
bestOm = mi.params.valuesdict()['Om']
bestH0 = mi.params.valuesdict()['H0']
bestOde= mi.params.valuesdict()['Ode']
#bestw0 = mi.params.valuedict()['w0']
plt.plot(zs[s],DM(zs[s],bestH0,bestOm,bestOde,w0))
plt.xlabel('Redshift (z)')
plt.ylabel('Distance Modulus (mag)')
lmfit.report_fit(mi)
# Out:
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 152
#     # data points      = 579
#     # variables        = 4
#     chi-square         = 561.871707
#     reduced chi-square = 0.97716819
#     Akaike info crit   = -9.38675202
#     Bayesian info crit = 8.05845789
# [[Variables]]
#     Om:   0.27840812 (init = 0.3)
#     H0:   69.9951449 (init = 70)
#     Ode:  0.72277985 (init = 0.7)
#     w0:  -1.07144483 (init = -1)

# %%
#%%prun -r -T "resultsw2"
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=300, steps=1500, thin=1,
                         params=p, is_weighted=True)

# %%
corner.corner(res.flatchain,labels=mi.var_names, truths=list(mi.params.valuesdict().values()))
