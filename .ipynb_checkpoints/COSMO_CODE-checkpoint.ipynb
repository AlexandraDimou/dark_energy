# %%
# %matplotlib inline
import numpy as np
import lmfit
import matplotlib.pyplot as plt
import pandas as pd
import corner
import astropy
import astropy.units as u
#import numba

# %%
columns=['name','redshift','distance_mod','DM_err','SN_prob']
rawdat=pd.read_csv('SCPUnion2.1_mu_vs_z.txt', sep='\s',names=columns, header=5, engine='python')

# %%
data=np.sort(rawdat.T, axis=0)
zs = rawdat.redshift
mm = rawdat.distance_mod
dm = rawdat.DM_err

# %%
from astropy.cosmology import wCDM

# %%
#because the equation of state must be constant
def w(z) :
    wz=w0
    return wz

# %%
#@numba.jit
def DM(z,H0,Om,Ode,w0):
    cosmo = wCDM(H0=H0* u.km / u.s / u.Mpc, Om0=Om,Ode0=Ode,w0=w0)
    DL=cosmo.luminosity_distance(z)
    mag=5*np.log10((DL/(10*u.pc)).decompose())
    #wz=cosmo.w(z)
    return mag

# %%
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'ignore', 'invalid': 'ignore', 'over': 'warn', 'under': 'ignore'}

# %%
p = lmfit.Parameters()
p.add_many(('Om',0.3,True,0.,2.),('H0',70.0,True,50.,100.),('Ode',0.7,True,0.,2.),('w0',-1.0,True,-1.5,0.5))

def residual(p):
    v = p.valuesdict()
    return (DM(zs,v['H0'],v['Om'],v['Ode'],v['w0'])-mm)/dm

# %%
print p
# Out:
# Parameters([('Om', <Parameter 'Om', 0.3, bounds=[0.0:2.0]>), ('H0', <Parameter 'H0', 70.0, bounds=[50.0:100.0]>), ('Ode', <Parameter 'Ode', 0.7, bounds=[0.0:2.0]>), ('w0', <Parameter 'w0', -1.0, bounds=[-1.5:0.5]>)])

# %%
mi = lmfit.minimize(residual, p, method='nelder', nan_policy='omit')

# %%
s = (zs.sort_values()).index
plt.errorbar(zs[s],mm[s],yerr=dm[s],fmt='o',alpha=0.4)
bestOm = mi.params.valuesdict()['Om']
bestH0 = mi.params.valuesdict()['H0']
bestOde= mi.params.valuesdict()['Ode']
#bestw = mi.params.valuedict()['w']
plt.plot(zs[s],DM(zs[s],bestH0,bestOm,bestOde,w0))
plt.xlabel('Redshift (z)')
plt.ylabel('Distance Modulus (mag)')
lmfit.report_fit(mi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-360882a39844> in <module>()
#       5 bestOde= mi.params.valuesdict()['Ode']
#       6 #bestw = mi.params.valuedict()['w']
# ----> 7 plt.plot(zs[s],DM(zs[s],bestH0,bestOm,bestOde,w0))
#       8 plt.xlabel('Redshift (z)')
#       9 plt.ylabel('Distance Modulus (mag)')
#
# <ipython-input-56-7deef17bc26e> in DM(z, H0, Om, Ode, w0)
#       1 #@numba.jit
#       2 def DM(z,H0,Om,Ode,w0):
# ----> 3     cosmo = wCDM(H0=H0* u.km / u.s / u.Mpc, Om0=Om,Ode0=Ode,w0=w0)
#       4     DL=cosmo.luminosity_distance(z)
#       5     mag=5*np.log10((DL/(10*u.pc)).decompose())
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in __init__(self, H0, Om0, Ode0, w0, Tcmb0, Neff, m_nu, Ob0, name)
#    1894         FLRW.__init__(self, H0, Om0, Ode0, Tcmb0, Neff, m_nu, name=name,
#    1895                       Ob0=Ob0)
# -> 1896         self._w0 = float(w0)
#    1897
#    1898         # Please see "Notes about speeding up integrals" for discussion
#
# TypeError: float() argument must be a string or a number

# %%
#%%prun -r -T "resultsw2"
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=300, steps=1500, thin=1,
                         params=p, is_weighted=True)

# %%
corner.corner(res.flatchain,labels=mi.var_names, truths=list(mi.params.valuesdict().values()))
