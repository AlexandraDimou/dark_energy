# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import lmfit
import astropy
import astropy.units as u
import corner
from astropy.cosmology import w0waCDM

# %%
from scipy import integrate

# %%
# My own version of code that determines the Hubble parameter at different redshifts
def H_zz(z,H0,Om,w0,w1):
    Ode=1-Om
    # quad only accepts scalars, so need to use a list comprehension to run through the whole array of z
    b = lambda zz : (1+w0+w1*(zz/(1+zz)))/(1+zz)
    b1 = [integrate.quadrature(b,0,zi) for zi in z]
    # Returns a list, so we convert to a numpy array
    B1=np.array(b1)
    x=(Om*(1+z)**3) + Ode*np.exp(3*B1[:,0])
    Hzz=H0*np.sqrt(x)
    return Hzz

# %%
# Astropy.cosmology version. Should be the same as above, but faster.
def Hz1(z1,H01,Om1,w01,wa1):
    cosmo = w0waCDM(H0=H01* u.km / u.s / u.Mpc, Om0=Om1,Ode0=1.0-Om1,w0=w01,wa=wa1)
#     E=cosmo.efunc(z1)
    I = cosmo.de_density_scale(z1)
    E = np.sqrt((Om1*(1+z1)**3) + (1-Om1)*I)
    HZ1 = H01*E
#     HZ1 = H01*I
    return HZ1

# %%
#Define  random redshifts
num_zs = 50
zs= np.linspace(0.01, 3., num=num_zs)

# %%
#From Planck observations for CPL mode
O_m= 0.3029
O_de= 1-O_m
w_0= -0.9414
w_1= -0.4303
H_0= 68.5265

# %%
#Hubble comoving parameter
Hz=Hz1(zs,H_0,O_m,w_0,w_1)/(1+zs)

# %%
#random error for Hz
error_sigma = 0.5
e1 = np.random.normal(0., error_sigma, Hz.shape)

# %%
H_zz= Hz + e1

# %%
plt.plot(zs,H_zz, '.')

# %%
p = lmfit.Parameters()
p.add_many(('Om1',0.3,True,0.,2.),
           ('H01',70.0,True,50.,100.),
#            ('Ode1',0.7,True,0.,2.),
           ('w01',-1.0,True,-2.,2.),
           ('wa1',-0.1,True,-1.,1.))

def residual(p):
    v = p.valuesdict()
    return (Hz1(zs,v['H01'],v['Om1'],v['w01'],v['wa1'])-H_zz)/error_sigma

# %%
mi = lmfit.minimize(residual, p, method='leastsq', nan_policy='omit')

# %%
plt.errorbar(zs,H_zz,yerr=error_sigma,fmt='o',alpha=0.2)
bestOm1 = mi.params.valuesdict()['Om1']
bestH01 = mi.params.valuesdict()['H01']
# bestOde1= mi.params.valuesdict()['Ode1']
bestw01 = mi.params.valuesdict()['w01']
bestwa1 = mi.params.valuesdict()['wa1']
plt.plot(zs,Hz1(zs,bestH01,bestOm1,bestw01,bestwa1))
plt.plot(zs,Hz)
plt.xlabel('Redshift (z)')
plt.ylabel('Comoving Hubble parameter')
lmfit.report_fit(mi)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 151
#     # data points      = 50
#     # variables        = 4
#     chi-square         = 47.5669814
#     reduced chi-square = 1.03406481
#     Akaike info crit   = 5.50579231
#     Bayesian info crit = 13.1538843
# [[Variables]]
#     Om1:  1.2351e-09 +/- 0.00131038 (106094138.15%) (init = 0.3)
#     H01:  68.3397444 +/- 0.36654580 (0.54%) (init = 70)
#     w01: -1.40332351 +/- 0.01849492 (1.32%) (init = -1)
#     wa1:  1.00000000 +/- 0.00930550 (0.93%) (init = -0.1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Om1, wa1) =  0.958
#     C(w01, wa1) =  0.950
#     C(H01, w01) = -0.873
#     C(Om1, w01) =  0.824
#     C(H01, wa1) = -0.724
#     C(Om1, H01) = -0.558

# %%
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=100, steps=5000,thin=1, nwalkers=10,
                         params=p, is_weighted=True, reuse_sampler=False)

# %%
corner.corner(res.flatchain,labels=res.var_names, truths=list(res.params.valuesdict().values()))

# %%
plt.plot(res.flatchain.H01)
