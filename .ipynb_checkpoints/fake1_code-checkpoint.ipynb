# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import lmfit
import astropy
import astropy.units as u

# %%
from scipy import integrate

# %%
def DM(z,H0,Om,w0,w1):
    c=299792.
    Ezz = lambda zz: 1e6*(c*(1+zz)/H0)*np.sqrt((Om*(1+zz)**3.)+((1-Om)*(1+zz)**(3.*(1.+w0+w1))*np.exp((-3.*w1*zz)/(1+zz))))
    DT=[integrate.quadrature(Ezz, 0, zi) for zi in z]
    DL=np.array(DT)
    mag=5*np.log10(DL[:,0]/10)
    return mag

# %%
zs= np.linspace(0.01, 5., num=1000)

# %%
#From WMAP observations for CPL mode
O_m=0.2855
w_0=-1.17
w_1=0.35
H0=70.

# %%
print DM(zs,70.,0.2855,-1.17,0.35)
# Out:
# [33.17216671 34.05869062 34.68982782 35.18097991 35.5835741  35.92505079
#  36.2217924  36.48436729 36.71999215 36.9338147  37.12963605 37.31034293
#  37.4781793  37.63492407 37.78201135 37.92061415 38.05170415 38.17609531
#  38.29447623 38.40743465 38.51547623 38.61903916 38.71850563 38.81421101
#  38.90645118 38.99548848 39.08155664 39.16486475 39.2456006  39.32393354
#  39.40001672 39.47398919 39.5459775  39.61609721 39.68445407 39.75114517
#  39.8162598  39.87988027 39.94208265 40.00293737 40.06250974 40.12086046
#  40.17804605 40.2341192  40.28912911 40.34312182 40.39614044 40.4482254
#  40.4994147  40.54974406 40.59924711 40.64795554 40.6958993  40.74310664
#  40.78960431 40.83541761 40.88057053 40.92508581 40.96898507 41.01228881
#  41.05501656 41.09718688 41.13881748 41.17992522 41.22052618 41.26063572
#  41.30026852 41.3394386  41.37815937 41.41644367 41.45430381 41.49175156
#  41.52879823 41.56545466 41.60173125 41.63763801 41.67318453 41.70838004
#  41.74323344 41.77775327 41.81194777 41.84582485 41.87939216 41.91265706
#  41.94562666 41.97830782 42.01070715 42.04283104 42.07468566 42.10627698
#  42.13761077 42.16869261 42.19952789 42.23012183 42.26047949 42.29060577
#  42.32050541 42.350183   42.379643   42.40888974 42.4379274  42.46676005
#  42.49539163 42.52382598 42.55206681 42.58011774 42.60798227 42.63566382
#  42.66316571 42.69049115 42.71764329 42.74462516 42.77143975 42.79808993
#  42.82457853 42.85090827 42.87708182 42.90310178 42.92897068 42.95469098
#  42.98026509 43.00569535 43.03098404 43.0561334  43.08114559 43.10602274
#  43.13076692 43.15538013 43.17986437 43.20422155 43.22845355 43.25256221
#  43.27654931 43.30041663 43.32416586 43.34779867 43.37131672 43.39472159
#  43.41801486 43.44119804 43.46427264 43.48724012 43.51010192 43.53285942
#  43.55551402 43.57806705 43.60051982 43.62287362 43.64512972 43.66728934
#  43.6893537  43.71132398 43.73320134 43.75498693 43.77668185 43.79828719
#  43.81980404 43.84123344 43.86257641 43.88383397 43.90500712 43.92609682
#  43.94710402 43.96802966 43.98887466 44.00963992 44.03032632 44.05093473
#  44.071466   44.09192097 44.11230046 44.13260527 44.1528362  44.17299403
#  44.19307951 44.21309341 44.23303645 44.25290936 44.27271286 44.29244764
#  44.31211439 44.33171379 44.3512465  44.37071318 44.39011431 44.40945083
#  44.42872337 44.44793223 44.46707816 44.48616176 44.50518361 44.52414427
#  52.29326068 52.2998726  52.30647886 52.31307949 52.31967449 52.32626387
#  52.33284764 52.33942582 52.34599839 52.35256539 52.35912682 52.36568268
#  52.37223299 52.37877776 52.38531699 52.39185069 52.39837888 52.40490156
#  52.41141874 52.41793043 52.42443665 52.43093739 52.43743267 52.4439225
#  52.45040688 52.45688583 52.46335935 52.46982745 52.47629015 52.48274745
#  52.48919936 52.49564588 52.50208704 52.50852272 52.51495316 52.52137824
#  52.527798   52.53421242 52.54062152 52.54702531 52.5534238  52.559817
#  52.56620491 52.57258754 52.57896491 52.58533701 52.59170387 52.59806548
#  52.60442186 52.61077301 52.61711894 52.62345967 52.6297952  52.63612553
#  52.64245069 52.64877066 52.65508547 52.66139512 52.66769963 52.67399899
#  52.68029321 52.68658231 52.6928663  52.69914517 52.70541895 52.71168763
#  52.71795123 52.72420975 52.73046321 52.7367116 ]

# %%
e = np.random.normal(0.2229, 0.126, 1000)

# %%
dist_mod=mm + e

# %%
plt.plot(zs,dist_mod, '.')

# %%
d = {'redshift': zs, 'distance_mod': dist_mod,'DM_err':e}

# %%
df = pd.DataFrame(data=d)

# %%
dat=np.sort(df.T, axis=0)
zz = df.redshift
dm = df.distance_mod
edm =df.DM_err

# %%
from astropy.cosmology import w0waCDM

# %%
def DM1(z,H0,Om,Ode,w0,wa):
    cosmo = w0waCDM(H0=H0* u.km / u.s / u.Mpc, Om0=Om,Ode0=Ode,w0=w0,wa=wa)
    DL=cosmo.luminosity_distance(z)
    mag1=5*np.log10((DL/(10*u.pc)).decompose())
    return mag1

# %%
p = lmfit.Parameters()
p.add_many(('Om',0.3,True,0.,2.),('H0',70.0,True,50.,100.),('Ode',0.7,True,0.,2.),('w0',-1.0,True,-2.,2.),('wa',-0.1,True,-1.,1.))

def residual(p):
    v = p.valuesdict()
    return (DM1(zz,v['H0'],v['Om'],v['Ode'],v['w0'],v['wa'])-dm)/edm

# %%
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'invalid': 'warn', 'over': 'warn', 'under': 'ignore'}

# %%
mi = lmfit.minimize(residual, p, method='nelder', nan_policy='omit')

# %%
s = (zz.sort_values()).index
plt.errorbar(zz[s],dm[s],yerr=edm[s],fmt='o',alpha=0.4)
bestOm = mi.params.valuesdict()['Om']
bestH0 = mi.params.valuesdict()['H0']
bestOde= mi.params.valuesdict()['Ode']
bestw0 = mi.params.valuesdict()['w0']
bestwa = mi.params.valuesdict()['wa']
plt.plot(zz[s],DM1(zz[s],bestH0,bestOm,bestOde,bestw0,bestwa))
plt.xlabel('Redshift (z)')
plt.ylabel('Distance Modulus (mag1)')
lmfit.report_fit(mi)
# Out:
# [[Fit Statistics]]
#     # fitting method   = Nelder-Mead
#     # function evals   = 771
#     # data points      = 308
#     # variables        = 5
#     chi-square         = 758.804818
#     reduced chi-square = 2.50430633
#     Akaike info crit   = 287.706600
#     Bayesian info crit = 306.357099
# [[Variables]]
#     Om:   0.00265332 (init = 0.3)
#     H0:   76.3683997 (init = 70)
#     Ode:  1.22653733 (init = 0.7)
#     w0:  -0.99247104 (init = -1)
#     wa:   0.14480228 (init = -0.1)

# %%
res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=300, steps=1500, thin=1,
                         params=p, is_weighted=True)
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.py:385: IntegrationWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   warnings.warn(msg, IntegrationWarning)
# emcee: Exception while calling your likelihood function:
#   params: [ 4.85489371e-02  7.30849753e+01  1.82199558e+00 -7.55394310e-01
#  -3.76988948e-01]
#   args: (<function residual at 0x7ff373446668>, Parameters([('Om', <Parameter 'Om', 0.0485489371117708, bounds=[0.0:2.0]>), ('H0', <Parameter 'H0', 73.08497531030405, bounds=[50.0:100.0]>), ('Ode', <Parameter 'Ode', 1.8219955767837888, bounds=[0.0:2.0]>), ('w0', <Parameter 'w0', -0.7553943098515464, bounds=[-2.0:2.0]>), ('wa', <Parameter 'wa', -0.3769889479129165, bounds=[-1.0:1.0]>)]), ['Om', 'H0', 'Ode', 'w0', 'wa'], array([[  0.,   2.],
#        [ 50., 100.],
#        [  0.,   2.],
#        [ -2.,   2.],
#        [ -1.,   1.]]))
#   kwargs: {'nan_policy': 'omit', 'userkws': {}, 'userargs': [], 'is_weighted': True, 'float_behavior': 'posterior'}
#   exception:
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/emcee/ensemble.py", line 519, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/lmfit/minimizer.py", line 2015, in _lnpost
#     out = userfcn(params, *userargs, **userkwargs)
#   File "<ipython-input-98-4b014b032c7d>", line 6, in residual
#     return (DM1(zz,v['H0'],v['Om'],v['Ode'],v['w0'],v['wa'])-dm)/edm
#   File "<ipython-input-97-62f3a0842fe1>", line 3, in DM1
#     DL=cosmo.luminosity_distance(z)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.py", line 1288, in luminosity_distance
#     return (1. + z) * self.comoving_transverse_distance(z)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.py", line 1194, in comoving_transverse_distance
#     return self._comoving_transverse_distance_z1z2(0, z)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.py", line 1223, in _comoving_transverse_distance_z1z2
#     dc = self._comoving_distance_z1z2(z1, z2)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.py", line 1168, in _comoving_distance_z1z2
#     return self._hubble_distance * vectorize_if_needed(f, z1, z2)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.py", line 2827, in vectorize_if_needed
#     return np.vectorize(func)(*x)
#   File "/usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.py", line 1972, in __call__
#     return self._vectorize_call(func=func, args=vargs)
#   File "/usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.py", line 2048, in _vectorize_call
#     outputs = ufunc(*inputs)
#   File "/home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.py", line 1167, in <lambda>
#     args=self._inv_efunc_scalar_args)[0]
#   File "/usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.py", line 341, in quad
#     points)
#   File "/usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.py", line 448, in _quad
#     return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-99ed2bdb206f> in <module>()
#       1 res = lmfit.minimize(residual, method='emcee', nan_policy='omit', burn=300, steps=1500, thin=1,
# ----> 2                          params=p, is_weighted=True)
#
# /home/alexandra/.local/lib/python2.7/site-packages/lmfit/minimizer.pyc in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2272                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2273                        calc_covar=calc_covar, **fit_kws)
# -> 2274     return fitter.minimize(method=method)
#
# /home/alexandra/.local/lib/python2.7/site-packages/lmfit/minimizer.pyc in minimize(self, method, params, **kws)
#    1924                         val.lower().startswith(user_method)):
#    1925                     kwargs['method'] = val
# -> 1926         return function(**kwargs)
#    1927
#    1928
#
# /home/alexandra/.local/lib/python2.7/site-packages/lmfit/minimizer.pyc in emcee(self, params, steps, nwalkers, burn, thin, ntemps, pos, reuse_sampler, workers, float_behavior, is_weighted, seed, progress)
#    1261             self._lastpos = output.coords
#    1262         else:
# -> 1263             output = self.sampler.run_mcmc(p0, steps)
#    1264             self._lastpos = output[0]
#    1265
#
# /usr/local/lib/python2.7/dist-packages/emcee/sampler.pyc in run_mcmc(self, pos0, N, rstate0, lnprob0, **kwargs)
#     170
#     171         for results in self.sample(pos0, lnprob0, rstate0, iterations=N,
# --> 172                                    **kwargs):
#     173             pass
#     174
#
# /usr/local/lib/python2.7/dist-packages/emcee/ensemble.pyc in sample(self, p0, lnprob0, rstate0, blobs0, iterations, thin, storechain, mh_proposal)
#     257                 for S0, S1 in [(first, second), (second, first)]:
#     258                     q, newlnp, acc, blob = self._propose_stretch(p[S0], p[S1],
# --> 259                                                                  lnprob[S0])
#     260                     if np.any(acc):
#     261                         # Update the positions, log probabilities and
#
# /usr/local/lib/python2.7/dist-packages/emcee/ensemble.pyc in _propose_stretch(self, p0, p1, lnprob0)
#     330         # Calculate the proposed positions and the log-probability there.
#     331         q = c[rint] - zz[:, np.newaxis] * (c[rint] - s)
# --> 332         newlnprob, blob = self._get_lnprob(q)
#     333
#     334         # Decide whether or not the proposals should be accepted.
#
# /usr/local/lib/python2.7/dist-packages/emcee/ensemble.pyc in _get_lnprob(self, pos)
#     380
#     381         # Run the log-probability calculations (optionally in parallel).
# --> 382         results = list(M(self.lnprobfn, [p[i] for i in range(len(p))]))
#     383
#     384         try:
#
# /usr/local/lib/python2.7/dist-packages/emcee/ensemble.pyc in __call__(self, x)
#     517     def __call__(self, x):
#     518         try:
# --> 519             return self.f(x, *self.args, **self.kwargs)
#     520         except:
#     521             import traceback
#
# /home/alexandra/.local/lib/python2.7/site-packages/lmfit/minimizer.pyc in _lnpost(theta, userfcn, params, var_names, bounds, userargs, userkws, float_behavior, is_weighted, nan_policy)
#    2013
#    2014     # now calculate the log-likelihood
# -> 2015     out = userfcn(params, *userargs, **userkwargs)
#    2016     out = _nan_policy(out, nan_policy=nan_policy, handle_inf=False)
#    2017
#
# <ipython-input-98-4b014b032c7d> in residual(p)
#       4 def residual(p):
#       5     v = p.valuesdict()
# ----> 6     return (DM1(zz,v['H0'],v['Om'],v['Ode'],v['w0'],v['wa'])-dm)/edm
#
# <ipython-input-97-62f3a0842fe1> in DM1(z, H0, Om, Ode, w0, wa)
#       1 def DM1(z,H0,Om,Ode,w0,wa):
#       2     cosmo = w0waCDM(H0=H0* u.km / u.s / u.Mpc, Om0=Om,Ode0=Ode,w0=w0,wa=wa)
# ----> 3     DL=cosmo.luminosity_distance(z)
#       4     mag1=5*np.log10((DL/(10*u.pc)).decompose())
#       5     return mag1
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in luminosity_distance(self, z)
#    1286             z = np.asarray(z)
#    1287
# -> 1288         return (1. + z) * self.comoving_transverse_distance(z)
#    1289
#    1290     def angular_diameter_distance_z1z2(self, z1, z2):
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in comoving_transverse_distance(self, z)
#    1192         """
#    1193
# -> 1194         return self._comoving_transverse_distance_z1z2(0, z)
#    1195
#    1196     def _comoving_transverse_distance_z1z2(self, z1, z2):
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in _comoving_transverse_distance_z1z2(self, z1, z2)
#    1221
#    1222         Ok0 = self._Ok0
# -> 1223         dc = self._comoving_distance_z1z2(z1, z2)
#    1224         if Ok0 == 0:
#    1225             return dc
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in _comoving_distance_z1z2(self, z1, z2)
#    1166         f = lambda z1, z2: quad(self._inv_efunc_scalar, z1, z2,
#    1167                              args=self._inv_efunc_scalar_args)[0]
# -> 1168         return self._hubble_distance * vectorize_if_needed(f, z1, z2)
#    1169
#    1170     def comoving_transverse_distance(self, z):
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in vectorize_if_needed(func, *x)
#    2825     """ Helper function to vectorize functions on array inputs"""
#    2826     if any(map(isiterable, x)):
# -> 2827         return np.vectorize(func)(*x)
#    2828     else:
#    2829         return func(*x)
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in __call__(self, *args, **kwargs)
#    1970             vargs.extend([kwargs[_n] for _n in names])
#    1971
# -> 1972         return self._vectorize_call(func=func, args=vargs)
#    1973
#    1974     def _get_ufunc_and_otypes(self, func, args):
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in _vectorize_call(self, func, args)
#    2046                       for a in args]
#    2047
# -> 2048             outputs = ufunc(*inputs)
#    2049
#    2050             if ufunc.nout == 1:
#
# /home/alexandra/.local/lib/python2.7/site-packages/astropy/cosmology/core.pyc in <lambda>(z1, z2)
#    1165         from scipy.integrate import quad
#    1166         f = lambda z1, z2: quad(self._inv_efunc_scalar, z1, z2,
# -> 1167                              args=self._inv_efunc_scalar_args)[0]
#    1168         return self._hubble_distance * vectorize_if_needed(f, z1, z2)
#    1169
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# KeyboardInterrupt:
